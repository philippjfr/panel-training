# %%
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[1], line 8
#       6 def app():
#       7     return pn.state.user_info
# ----> 8 pn.io.server.get_server(
#       9     app,
#      10     oauth_provider='code',
#      11     oauth_extra_params={
#      12         'AUTHORIZE_URL': 'https://auth-qa.hconnect.digital/api/identity/connect/authorize',
#      13         'TOKEN_URL': 'https://auth-qa.hconnect.digital/api/identity/connect/token',
#      14         'USER_URL': 'https://auth-qa.hconnect.digital/api/identity/connect/userinfo'
#      15     },
#      16     oauth_key='PREDICT',
#      17     login_endpoint='/auth',
#      18     port=5006,
#      19     cookie_secret='foo'
#      20 )
#
# File ~/minicondam1/envs/hm-panel/lib/python3.11/site-packages/panel/io/server.py:1184, in get_server(panel, port, address, websocket_origin, loop, show, start, title, verbose, location, admin, static_dirs, basic_auth, oauth_provider, oauth_key, oauth_secret, oauth_redirect_uri, oauth_extra_params, oauth_error_template, cookie_secret, oauth_encryption_key, logout_template, session_history, **kwargs)
#    1181     config.oauth_redirect_uri = oauth_redirect_uri # type: ignore
#    1182 opts['cookie_secret'] = config.cookie_secret
# -> 1184 server = Server(apps, port=port, **opts)
#    1185 if verbose:
#    1186     address = server.address or 'localhost'
#
# File ~/minicondam1/envs/hm-panel/lib/python3.11/site-packages/panel/io/server.py:376, in Server.__init__(self, *args, **kwargs)
#     375 def __init__(self, *args, **kwargs):
# --> 376     super().__init__(*args, **kwargs)
#     377     if state._admin_context:
#     378         state._admin_context._loop = self._loop
#
# File ~/minicondam1/envs/hm-panel/lib/python3.11/site-packages/bokeh/server/server.py:430, in Server.__init__(self, applications, io_loop, http_server_kwargs, **kwargs)
#     428         extra_websocket_origins = []
#     429 else:
# --> 430     sockets, self._port = bind_sockets(opts.address, opts.port)
#     431     self._address = opts.address
#     433     extra_websocket_origins = create_hosts_allowlist(opts.allow_websocket_origin, self.port)
#
# File ~/minicondam1/envs/hm-panel/lib/python3.11/site-packages/bokeh/server/util.py:68, in bind_sockets(address, port)
#      48 def bind_sockets(address: str | None, port: int) -> tuple[list[socket], int]:
#      49     ''' Bind a socket to a port on an address.
#      50
#      51     Args:
#    (...)
#      66
#      67     '''
# ---> 68     ss = netutil.bind_sockets(port=port or 0, address=address)
#      69     assert len(ss)
#      70     ports = {s.getsockname()[1] for s in ss}
#
# File ~/minicondam1/envs/hm-panel/lib/python3.11/site-packages/tornado/netutil.py:162, in bind_sockets(port, address, family, backlog, flags, reuse_port)
#     160 sock.setblocking(False)
#     161 try:
# --> 162     sock.bind(sockaddr)
#     163 except OSError as e:
#     164     if (
#     165         errno_from_exception(e) == errno.EADDRNOTAVAIL
#     166         and address == "localhost"
#    (...)
#     178         # might be a real problem like a typo in a
#     179         # configuration.
#
# OSError: [Errno 48] Address already in use

# %%
# Out:
# [('/components/(.*)', <class 'panel.io.server.ComponentResourceHandler'>, {}), ('/auth', <class 'panel.auth.AuthorizationCodeLoginHandler'>), ('/logout', <class 'panel.auth.LogoutHandler'>)]

# %%
pn.state.cache
# Out:
# {'code': {'client_id': 'PREDICT',
#   'response_type': 'code',
#   'scope': 'global,openid',
#   'state': 'eyJzdGF0ZV9pZCI6ICIyNmFhNWVjNzcxNzU0ZjhjOGE4ZTkwNzMwODI3Nzk3MiIsICJuZXh0X3VybCI6ICIvYXV0aCJ9',
#   'response_mode': 'query',
#   'code_challenge': 'wMFYMSnD2EKejhnlUWw_8FeZtUiQVrrI3G-yA6rGar4',
#   'code_challenge_method': 'S256',
#   'redirect_uri': 'http://localhost:5006/auth'}}

# %%
1. My ideas for refactoring
2. Single page vs multi page
3. Custom templates

# %%
import param

# %%
from panel.reactive import ReactiveHTML

class Cookies(ReactiveHTML):

    _cookies = param.String()

    _set = param.String(allow_None=True)
    
    _scripts = {
        'render': 'data._cookies = document.cookie',
        'set': 'if (data._set) { document.cookie = model._set; }'
    }

    def set_cookie(self, cookie):
        self._set = cookie
        self._set = None

cookie = Cookies()
cookie
# Out:
# Cookies()

# %%
cookie.set_cookie("test=woo; SameSite=None;")

# %%
cookie._cookies
# Out:
# '_xsrf=2|19063678|92edf419f50fb561013691b99c52ad2c|1695814944'
